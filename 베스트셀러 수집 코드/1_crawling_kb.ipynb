# %%
import requests as req
from bs4 import BeautifulSoup as bs
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time
import pandas as pd

# %%
options = Options()
# options.add_argument('--headless')
options.add_argument("--start-maximized")
options.add_experimental_option("detach", True)

driver = webdriver.Chrome(options=options)
driver.get("https://store.kyobobook.co.kr/bestseller/total/monthly?page=1&per=50")
time.sleep(3)

ol = driver.find_element(By.CSS_SELECTOR, "ol.grid.border-t.border-gray-400.grid-cols-1.pt-9")
li10_kb = ol.find_elements(By.XPATH, '/html/body/div[1]/main/section/div/div/section/ol[1]/li')
li40_kb = ol.find_elements(By.XPATH, '/html/body/div[1]/main/section/div/div/section/ol[2]/li')
li_kb = li10_kb + li40_kb

links_kb = []
titles_kb = []
authors_kb = []
genres_kb = []
for i in range(0,30):
#     title = li[i].find_element(By.CSS_SELECTOR, "a.font-weight-medium").text
    link_kb = li_kb[i].find_element(By.CSS_SELECTOR, "a.font-weight-medium").get_attribute("href")
    links_kb.append(link_kb)

for j in links_kb:
    driver.get(j)
    time.sleep(2)
    title_kb = driver.find_element(By.CSS_SELECTOR, "span.prod_title").text
    author_kb = driver.find_element(By.CSS_SELECTOR, ".author > a").text
    genre_kb = driver.find_elements(By.CSS_SELECTOR, '.btn_sub_depth')[1].text
    titles_kb.append(title_kb)
    authors_kb.append(author_kb)
    genres_kb.append(genre_kb)
driver.quit()

# print(titles_kb)
# print(authors_kb)
# print(genres_kb)

for i in range(len(genres_kb)):
    if genres_kb[i] == '소설':
        genres_kb[i] = '소설/시/희곡/에세이'
    elif genres_kb[i] == '시/에세이':
        genres_kb[i] = '소설/시/희곡/에세이'
print(genres_kb)

bookData_kb = []
for k in range(0,30):
    bookData_kb.append({
            "순위": k+1,
            "제목": titles_kb[k],
            "작가": authors_kb[k],
            "장르": genres_kb[k]
    })
print(bookData_kb)

books_kb_df = pd.DataFrame(bookData_kb)
books_kb_df
# Out:
# ['소설/시/희곡/에세이', '소설/시/희곡/에세이', '소설/시/희곡/에세이', '소설/시/희곡/에세이', '경제/경영', '경제/경영', '소설/시/희곡/에세이', '소설/시/희곡/에세이', '인문', '소설/시/희곡/에세이', '소설/시/희곡/에세이', '경제/경영', '소설/시/희곡/에세이', '자기계발', '소설/시/희곡/에세이', '자기계발', '소설/시/희곡/에세이', '인문', '소설/시/희곡/에세이', '경제/경영', '인문', '소설/시/희곡/에세이', '인문', '경제/경영', '자기계발', '만화', '소설/시/희곡/에세이', '어린이(초등)', '경제/경영', '자기계발']
# [{'순위': 1, '제목': '소년이 온다', '작가': '한강', '장르': '소설/시/희곡/에세이'}, {'순위': 2, '제목': '채식주의자', '작가': '한강', '장르': '소설/시/희곡/에세이'}, {'순위': 3, '제목': '작별하지 않는다', '작가': '한강', '장르': '소설/시/희곡/에세이'}, {'순위': 4, '제목': '흰', '작가': '한강', '장르': '소설/시/희곡/에세이'}, {'순위': 5, '제목': '트렌드 코리아 2025', '작가': '김난도', '장르': '경제/경영'}, {'순위': 6, '제목': '트럼프 2.0 시대', '작가': '박종훈', '장르': '경제/경영'}, {'순위': 7, '제목': '서랍에 저녁을 넣어 두었다', '작가': '한강', '장르': '소설/시/희곡/에세이'}, {'순위': 8, '제목': '희랍어 시간', '작가': '한강', '장르': '소설/시/희곡/에세이'}, {'순위': 9, '제목': '넥서스', '작가': '유발 하라리', '장르': '인문'}, {'순위': 10, '제목': '어른의 행복은 조용하다', '작가': '태수', '장르': '소설/시/희곡/에세이'}, {'순위': 11, '제목': '모순', '작가': '양귀자', '장르': '소설/시/희곡/에세이'}, {'순위': 12, '제목': '가난한 찰리의 연감', '작가': '찰리 멍거', '장르': '경제/경영'}, {'순위': 13, '제목': '우리는 사랑 안에 살고 있다', '작가': '유혜주', '장르': '소설/시/희곡/에세이'}, {'순위': 14, '제목': '고전이 답했다 마땅히 살아야 할 삶에 대하여(나만의 책 만들기 에디션)', '작가': '고명환', '장르': '자기계발'}, {'순위': 15, '제목': '디 에센셜: 한강(무선 보급판)', '작가': '한강', '장르': '소설/시/희곡/에세이'}, {'순위': 16, '제목': '퓨처 셀프 30만 부 기념 스페셜 에디션', '작가': '벤저민 하디', '장르': '자기계발'}, {'순위': 17, '제목': '급류', '작가': '정대건', '장르': '소설/시/희곡/에세이'}, {'순위': 18, '제목': '하루 한 장 나의 어휘력을 위한 필사 노트', '작가': '유선경', '장르': '인문'}, {'순위': 19, '제목': '작은 땅의 야수들(리커버 무선판)', '작가': '김주혜', '장르': '소설/시/희곡/에세이'}, {'순위': 20, '제목': '시대예보: 호명사회', '작가': '송길영', '장르': '경제/경영'}, {'순위': 21, '제목': '인생의 의미', '작가': '토마스 힐란드 에릭센', '장르': '인문'}, {'순위': 22, '제목': '여수의 사랑', '작가': '한강', '장르': '소설/시/희곡/에세이'}, {'순위': 23, '제목': '나는 왜 남들보다 쉽게 지칠까', '작가': '최재훈', '장르': '인문'}, {'순위': 24, '제목': '머니 트렌드 2025', '작가': '정태익', '장르': '경제/경영'}, {'순위': 25, '제목': '김미경의 딥마인드', '작가': '김미경', '장르': '자기계발'}, {'순위': 26, '제목': '원피스 109: 네 편', '작가': 'EIICHIRO ODA', '장르': '만화'}, {'순위': 27, '제목': '검은 사슴', '작가': '한강', '장르': '소설/시/희곡/에세이'}, {'순위': 28, '제목': 'who? 스페셜 아이브', '작가': '조약돌', '장르': '어린이(초등)'}, {'순위': 29, '제목': '박태웅의 AI 강의 2025', '작가': '박태웅', '장르': '경제/경영'}, {'순위': 30, '제목': '린치핀', '작가': '세스 고딘', '장르': '자기계발'}]
#     순위                                       제목            작가           장르
# 0    1                                   소년이 온다            한강  소설/시/희곡/에세이
# 1    2                                    채식주의자            한강  소설/시/희곡/에세이
# 2    3                                 작별하지 않는다            한강  소설/시/희곡/에세이
# 3    4                                        흰            한강  소설/시/희곡/에세이
# 4    5                             트렌드 코리아 2025           김난도        경제/경영
# 5    6                               트럼프 2.0 시대           박종훈        경제/경영
# 6    7                           서랍에 저녁을 넣어 두었다            한강  소설/시/희곡/에세이
# 7    8                                   희랍어 시간            한강  소설/시/희곡/에세이
# 8    9                                      넥서스        유발 하라리           인문
# 9   10                             어른의 행복은 조용하다            태수  소설/시/희곡/에세이
# 10  11                                       모순           양귀자  소설/시/희곡/에세이
# 11  12                               가난한 찰리의 연감         찰리 멍거        경제/경영
# 12  13                          우리는 사랑 안에 살고 있다           유혜주  소설/시/희곡/에세이
# 13  14  고전이 답했다 마땅히 살아야 할 삶에 대하여(나만의 책 만들기 에디션)           고명환         자기계발
# 14  15                        디 에센셜: 한강(무선 보급판)            한강  소설/시/희곡/에세이
# 15  16                   퓨처 셀프 30만 부 기념 스페셜 에디션        벤저민 하디         자기계발
# 16  17                                       급류           정대건  소설/시/희곡/에세이
# 17  18                  하루 한 장 나의 어휘력을 위한 필사 노트           유선경           인문
# 18  19                       작은 땅의 야수들(리커버 무선판)           김주혜  소설/시/희곡/에세이
# 19  20                               시대예보: 호명사회           송길영        경제/경영
# 20  21                                   인생의 의미   토마스 힐란드 에릭센           인문
# 21  22                                   여수의 사랑            한강  소설/시/희곡/에세이
# 22  23                         나는 왜 남들보다 쉽게 지칠까           최재훈           인문
# 23  24                              머니 트렌드 2025           정태익        경제/경영
# 24  25                                김미경의 딥마인드           김미경         자기계발
# 25  26                             원피스 109: 네 편  EIICHIRO ODA           만화
# 26  27                                    검은 사슴            한강  소설/시/희곡/에세이
# 27  28                             who? 스페셜 아이브           조약돌      어린이(초등)
# 28  29                          박태웅의 AI 강의 2025           박태웅        경제/경영
# 29  30                                      린치핀         세스 고딘         자기계발
